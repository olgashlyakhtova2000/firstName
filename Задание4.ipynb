# %% [markdown]
# <a href="https://colab.research.google.com/github/olgashlyakhtova2000/firstName/blob/main/%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B54.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, Math
import matplotlib
import matplotlib.pyplot as plt

# %%
def add(x, y):
  return ['+', x, y]

def mul(x, y):
  return ['*', x, y]

def div(x, y):
  return ["/", x, y]

def sub(x, y):
  return ["-", x, y]

def pow(x, y):
  return ["^", x, y]

def neg(x):
  return ["--", x]

# %%
def fsqrt(x):
  return ['sqrt', x]

def fsin(x):
  return ['sin', x]

def fcos(x):
  return ['cos', x]
def ftan(x):
  return ['tan', x]

def fctan(x):
  return ['ctan', x]

def fsinh(x):
  return ['sinh', x]

def fcosh(x):
  return ['cosh', x]

def ftanh(x):
  return ['tanh', x]

def fctanh(x):
  return ['ctanh', x]

def fasinh(x):
  return ['asinh', x]

def facosh(x):
  return ['acosh', x]

def fatanh(x):
  return ['atanh', x]

def factanh(x):
  return ['actanh', x]

def fasin(x):
  return ['asim', x]

def facos(x):
  return ['acos', x]

def fatan(x):
  return ['atan', x]

def factan(x):
  return ['actan', x]

def fln(x):
  return ['ln', x]

# %%
def flg(x):
  return ['lg', x]
def flog(x, a):
  return ['log_a', x, a]
def fsqrtn(x, n):
  return ['sqrt_n', x, n]

# %%
def check(x):
  if isinstance(x, Expression):
    return x
  return Expression(x)

class Expression:
  def __init__(self, f):
    self.f = f
  def __add__(self, x):
    x = check(x)
    return Expression(add(self.f, x.f))
  def __sub__(self, x):
    x = check(x)
    return Expression(sub(self.f, x.f))
  def __mul__(self, x):
    x = check(x)
    return Expression(mul(self.f, x.f))
  def __truediv__(self, x):
    x = check(x)
    return Expression(div(self.f, x.f))
  def __pow__(self, x):
    x = check(x)
    return Expression(pow(self.f, x.f))
  def __radd__(self, x):
    x = check(x)
    return Expression(add(x.f, self.f))
  def __rsub__(self, x):
    x = check(x)
    return Expression(sub(x.f, self.f))
  def __rmul__(self, x):
    x = check(x)
    return Expression(mul(x.f, self.f))
  def __rtruediv__(self, x):
    x = check(x)
    return Expression(div(x.f, self.f))
  def __rpow__(self, x):
    x = check(x)
    return Expression(pow(x.f, self.f))
  def __neg__(self):
    return Expression(neg(self.f))
  def subs(self, var, val):
    return Expression(substitute(self.f, var, val))
  def evalf(self):
    return evaluate(self.f)
  def __str__(self):
    return expr2latex(self.f)
  def show(self):
    display(Math(expr2latex(self.f)))
  def diff(self, var):
    var = check(var).f
    return Expression(differentiate(self.f, var))

# %%
def sqrt(x):
  x = check(x)
  t =x.f
  r = fsqrt(t)
  return Expression(r)

def sin(x):
  return Expression(fsin(check(x).f))

def cos(x):
  return Expression(fcos(check(x).f))

def tan(x):
    return Expression(ftan(check(x).f))
def ctan(x):
    return Expression(fctan(check(x).f))
def acos(x):
    return Expression(facos(check(x).f))
def asin(x):
    return Expression(fasin(check(x).f))
def atan(x):
    return Expression(fatan(check(x).f))
def actan(x):
    return Expression(fcatan(check(x).f))
def sinh(x):
    return Expression(fsinh(check(x).f))
def cosh(x):
    return Expression(fcosh(check(x).f))
def tanh(x):
    return Expression(ftanh(check(x).f))
def ctanh(x):
    return Expression(fctanh(check(x).f))
def asinh(x):
    return Expression(fasinh(check(x).f))
def aacosh(x):
    return Expression(facosh(check(x).f))
def atanh(x):
    return Expression(fatanh(check(x).f))
def ctanh(x):
    return Expression(factanh(check(x).f))

def ln(x):
  return Expression(fln(check(x).f))

# %%
  def lg(x):
    return Expression(flg(check(x).f))
  def log_a(x, a):
    return Expression(flog(check(x).f, check(a).f))

# %%
def substitute(f, var, val):
  val = check(val).f
  if f == var:
    return val
  elif isinstance(f, list):
    y = [f[0]]
    for i in range(1, len(f)):
      t = substitute(f[i], var, val)
      y.append(t)
    return y
  else:
    return f

# %%
import math

def evaluate(f):
  if isinstance(f, (int, float)):
    return f
  elif isinstance(f, list):
    if f[0] == "+": 
      return evaluate(f[1]) + evaluate(f[2])
    elif f[0] == "*":
      return evaluate(f[1]) * evaluate(f[2])
    elif f[0] == "sqrt":
      return math.sqrt(evaluate(f[1]))
    elif f[0] == "sqrt_n":
      return evaluate(f[1])**(1/evaluate(f[2]))
    elif f[0] == "sin":
      return math.sin(evaluate(f[1]))
    elif f[0] == "cos":
      return math.cos(evaluate(f[1]))
        elif f[0] == "tan":
      return tan(evaluate(f[1]))
    elif f[0] == "ctan":
      return 1/tan(evaluate(f[1]))
    elif f[0] == "asin":
      return asin(evaluate(f[1]))
    elif f[0] == "acos":
      return acos(evaluate(f[1]))
    elif f[0] == "atan":
      return atan(evaluate(f[1]))
    elif f[0] == "actan":
      return 1/atan(evaluate(f[1]))
    elif f[0] == "sinh":
      return sinh(evaluate(f[1]))
    elif f[0] == "cosh":
      return cosh(evaluate(f[1]))
    elif f[0] == "tanh":
      return tanh(evaluate(f[1]))
    elif f[0] == "ctanh":
      return 1/tanh(evaluate(f[1]))      
    elif f[0] == "asinh":
      return asinh(evaluate(f[1]))
    elif f[0] == "acosh":
      return acosh(evaluate(f[1]))
    elif f[0] == "atanh":
      return atanh(evaluate(f[1]))
    elif f[0] == "actanh":
      return 1/atanh(evaluate(f[1]))
    elif f[0] == "lg":
      return log10(evaluate(f[1]))  
    elif f[0] == "log_a":
      return log(evaluate(f[1]), evaluate(f[2]))  
  return None

# %%
def expr2latex(x):
  if isinstance(x, (int, float)):
    return str(x)
  if isinstance(x, str):
    return x
  if isinstance(x, list):
    if x[0] == "+":
      return expr2latex(x[1]) + "+" + expr2latex(x[2])
    if x[0] == "-":
      return expr2latex(x[1]) + "-" + expr2latex(x[2])
    if x[0] == "*":
      left = expr2latex(x[1])
      if isinstance(x[1], list) and x[1][0] == "+":
        left = "\\left(" + left + "\\right)"
      right = expr2latex(x[2])
      if isinstance(x[2], list) and x[2][0] == "+":
        right = "\\left(" + right + "\\right)"
      return left + "\\cdot " + right
    if x[0] == "/":
      return "\\dfrac{" + expr2latex(x[1]) + "}{" + expr2latex(x[2]) + "}"
    if x[0] == "^":
      left = expr2latex(x[1])
      if isinstance(x[1], list):
        left = "\\left(" + left + "\\right)"
      right = expr2latex(x[2])
      return "{" + left + "}^{" + right + "}"
    if x[0] == "--":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "-{" + a + "}"
    if x[0] == "sqrt":
      a = expr2latex(x[1])
      return "\\sqrt{" + a + "}"
    if x[0] == "sin":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\sin{" + a + "}"
    if x[0] == "cos":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\cos{" + a + "}"
    if x[0] == "ln":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\ln{" + a + "}"
    elif x[0]=="lg":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\lg{" + a + "}"
    elif x[0]=="log_a":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\log_"+str(x[2])+"{" + a + "}"
    elif x[0]=="acos":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\arccos{" + a + "}"
    elif x[0]=="asin":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\arcsin{" + a + "}"
    elif x[0]=="atan":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\arctan{" + a + "}"
    elif x[0]=="actan":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\cot{" + a + "}"
    elif x[0]=="cosh":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\cosh{" + a + "}"
    elif x[0]=="sinh":
      a = expr2latex(x[1])
      if isinstance(x[1], list):
        a = "\\left(" + a + "\\right)"
      return "\\sinh{" + a + "}"

# %%
def differentiate(f, x):
  if isinstance(f, int):
    return 0
  if f == x:
    return 1
  if isinstance(f, str):
    return 0
  if isinstance(f, list):
    if f[0] == "+":
      u, v = f[1], f[2]
      u1, v1 = differentiate(u, x), differentiate(v, x)
      return add(u1, v1)
    if f[0] == "-":
      u, v = f[1], f[2]
      u1, v1 = differentiate(u, x), differentiate(v, x)
      return sub(u1, v1)      
    if f[0] == "*":
      u, v = f[1], f[2]
      u1, v1 = differentiate(u, x), differentiate(v, x)
      return add(mul(u1, v), mul(u, v1))   
    if f[0] == "/":
      u, v = f[1], f[2]
      u1, v1 = differentiate(u, x), differentiate(v, x)
      return div(sub(mul(u1, v), mul(u, v1)), pow(v, 2))   
    if f[0] == "^":
      u, v = f[1], f[2]
      u1, v1 = differentiate(u, x), differentiate(v, x)
      p1, p2 = pow(u, v), pow(u, sub(v, 1))
      s1 = mul(p1, mul(v1, fln(u)))
      s2 = mul(v, mul(p2, u1))
      return add(s1, s2) 
    if f[0] == "--":
      u = f[1]
      u1 = differentiate(u, x)
      return neg(u1)
    if f[0] == "ln":
      u = f[1]
      u1 = differentiate(u, x)
      return div(u1, u)
    if f[0] == "sin":
      u = f[1]
      u1 = differentiate(u, x)
      return mul(fcos(u), u1)
    if f[0] == "cos":
      u = f[1]
      u1 = differentiate(u, x)
      return mul(neg(fsin(u)), u1)
    if f[0] == "sqrt":
      u = f[1]
      u1 = differentiate(u, x)
      return div(u1, mul(2, fsqrt(u)))
    if f[0]=="tan":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(div(1, pow(fcos(u),2)), u1)
    if f[0]=="ctan":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(neg(div(1, pow(fsin(u),2))), u1)   
    if f[0]=="asin":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(div(1, fsqrt(sub(1,pow(u,2)))), u1)    
    if f[0]=="acos":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(neg(div(1, fsqrt(sub(1,pow(u,2))))), u1)    
    if f[0]=="atan":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(div(1, add(1,pow(u,2))), u1)     
    if f[0]=="catan":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(neg(div(1, add(1,pow(u,2)))), u1)   
    if f[0]=="sinh":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(mul(ftan(u), fsinh(u)), u1)    
    if f[0]=="cosh":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(neg(mul(fctan(u), fcosh(u))), u1)    
    if f[0]=="tanh":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(div(1,pow(fsinh(u),2)), u1)    
    if f[0]=="ctanh":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(neg(div(1,pow(fcosh(u),2))), u1)    
    if f[0]=="asinh":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(div(1, fsqrt(add(pow(u,2),1))), u1)    
    if f[0]=="acosh":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(div(1, fsqrt(sub(pow(u,2),1))), u1)    
    if f[0]=="atanh":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(div(1,sub(1,pow(u,2))), u1)    
    if f[0]=="actanh":
      u=f[1]
      u1 == differentiate(u,x)
      return mul(neg(div(1,sub(pow(u,2),1))), u1)

# %%
x = Expression('x')
z = 2 ** x
z.show()
z.diff(x).show()
# Out:
# $${2}^{x}$$
# $${2}^{x}\cdot 1\cdot \ln{2}+x\cdot {2}^{x-1}\cdot 0$$
